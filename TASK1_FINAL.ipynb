# %%
from selenium import webdriver
import os
import time
import pandas as pd
driver=webdriver.Chrome(executable_path=r"C:\Users\merit\chromedriver.exe")
driver.maximize_window()
driver.get("https://www.cricbuzz.com/cricket-match/live-scores")
driver.find_element_by_xpath("//div[@id='rankingDropDown']").click()
time.sleep(2)
#------------------------------BATTING----------------------------------#
driver.find_element_by_xpath("//a[@id='batsmen-tests-tab']").click()
a=driver.find_elements_by_xpath("//a[@id='batsmen-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l=[]
for i in a:
    l.append(i.text.split("\n"))
print(l,end=" ")
driver.find_element_by_xpath("//a[@id='batsmen-odis-tab']").click()
c=driver.find_elements_by_xpath("//a[@id='batsmen-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l1=[]
for j in c:
    if j.text!='':
        l1.append(j.text.split("\n"))
print(l1,end=" ")
driver.find_element_by_xpath("//a[@id='batsmen-t20s-tab']").click()
d=driver.find_elements_by_xpath("//a[@id='batsmen-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l2=[]
for k in d:
    if k.text!='':
        l2.append(k.text.split("\n"))
print(l2,end=" ")
# dataframe
writer = pd.ExcelWriter('Batting_.xlsx', engine='xlsxwriter')
df = pd.DataFrame(l, columns = ["Position","NAN","Player","Country","Rating"])
df1 = pd.DataFrame(l1, columns = ["Position","NAN","Player","Country","Rating"])
df2 = pd.DataFrame(l2, columns = ["Position","NAN","Player","Country","Rating"])
df2.drop(columns='NAN',axis="columns",inplace=True)
df1.drop(columns='NAN',axis="columns",inplace=True)
df.drop(columns='NAN',axis="columns",inplace=True)
time.sleep(2)
writer = pd.ExcelWriter('Batting_.xlsx', engine='xlsxwriter')
writer.save()
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('Batting_.xlsx', engine='xlsxwriter')
# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Batting-TEST', index=False)
df1.to_excel(writer,sheet_name='Batting-ODI', index=False)
df2.to_excel(writer,sheet_name='Batting-T20', index=False)
# Close the Pandas Excel writer and output the Excel file.
writer.save()
reader = pd.read_excel(r'Batting_.xlsx')
print(reader)
df.to_excel(writer,index=False,header=False)
df1.to_excel(writer,index=False,header=False)
df2.to_excel(writer,index=False,header=False)
#------------------------------BOWLING----------------------------------#
driver.find_element_by_xpath("//a[@id='bowlers-tab']").click()
#driver.find_element_by_xpath("//a[@id='//a[@id='bowlers-tests-tab']']").click()
#driver.find_elements_by_xpath("//a[@id='bowlers-tests-tab']").click()
b=driver.find_elements_by_xpath("//a[@id='bowlers-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l3=[]
for p in b:
    if p.text!='':
        l3.append(p.text.split("\n"))
print(l3,end=" ")
driver.find_element_by_xpath("//a[@id='bowlers-odis-tab']").click()
e=driver.find_elements_by_xpath("//a[@id='bowlers-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l4=[]
for q in e:
    if q.text!='':
        l4.append(q.text.split("\n"))
print(l4,end=" ")
driver.find_element_by_xpath("//a[@id='bowlers-t20s-tab']").click()
f=driver.find_elements_by_xpath("//a[@id='bowlers-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l5=[]
for r in f:
    if r.text!='':
        l5.append(r.text.split("\n"))
print(l5,end=" ")
# dataframe
writer1 = pd.ExcelWriter('Bowling_.xlsx', engine='xlsxwriter')
df3 = pd.DataFrame(l3, columns = ["Position","NAN","Player","Country","Rating"])
df3.drop(columns='NAN',axis="columns",inplace=True)
df4 = pd.DataFrame(l4, columns = ["Position","NAN","Player","Country","Rating"])
df4.drop(columns='NAN',axis="columns",inplace=True)
df5 = pd.DataFrame(l5, columns = ["Position","NAN","Player","Country","Rating"])
df5.drop(columns='NAN',axis="columns",inplace=True)
time.sleep(2)
writer1 = pd.ExcelWriter('Bowling_.xlsx', engine='xlsxwriter')
writer1.save()
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer1 = pd.ExcelWriter('Bowling_.xlsx', engine='xlsxwriter')
# Convert the dataframe to an XlsxWriter Excel object.
df3.to_excel(writer1, sheet_name='Bowling-TEST', index=False)
df4.to_excel(writer1, sheet_name='Bowling-ODI', index=False)
df5.to_excel(writer1, sheet_name='Bowling-T20', index=False)
# Close the Pandas Excel writer and output the Excel file.
writer1.save()
reader1 = pd.read_excel(r'Bowling_.xlsx')
print(reader1)
df3.to_excel(writer1,index=False,header=False)
df4.to_excel(writer1,index=False,header=False)
df5.to_excel(writer1,index=False,header=False)
#------------------------------ALL ROUNDERS----------------------------------#
driver.find_element_by_xpath("//a[@id='all-rounders-tab']").click()
g=driver.find_elements_by_xpath("//a[@id='allrounders-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l6=[]
for l1 in g:
    if l1.text!='':
        l6.append(l1.text.split("\n"))
print(l6,end=" ")
driver.find_element_by_xpath("//a[@id='allrounders-odis-tab']").click()
h=driver.find_elements_by_xpath("//a[@id='allrounders-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l7=[]
for l2 in h:
    if l2.text!='':
        l7.append(l2.text.split("\n"))
print(l7,end=" ")
driver.find_element_by_xpath("//a[@id='allrounders-t20s-tab']").click()
x=driver.find_elements_by_xpath("//a[@id='allrounders-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")
l8=[]
for l3 in x:
    if l3.text!='':
        l8.append(l3.text.split("\n"))
print(l8,end=" ")
# dataframe
writer2 = pd.ExcelWriter('All_rounders.xlsx', engine='xlsxwriter')
df6 = pd.DataFrame(l6, columns = ["Position","NAN","Player","Country","Rating"])
df6.drop(columns='NAN',axis="columns",inplace=True)
df7 = pd.DataFrame(l7, columns = ["Position","NAN","Player","Country","Rating"])
df7.drop(columns='NAN',axis="columns",inplace=True)
df8 = pd.DataFrame(l8, columns = ["Position","NAN","Player","Country","Rating"])
df8.drop(columns='NAN',axis="columns",inplace=True)
time.sleep(2)
writer2 = pd.ExcelWriter('All_rounders.xlsx', engine='xlsxwriter')
writer2.save()
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer2 = pd.ExcelWriter('All_rounders.xlsx', engine='xlsxwriter')
# Convert the dataframe to an XlsxWriter Excel object.
df6.to_excel(writer2, sheet_name='All_rounders-TEST', index=False)
df7.to_excel(writer2, sheet_name='All_rounders-ODI', index=False)
df8.to_excel(writer2, sheet_name='All_rounders-T20', index=False)
# Close the Pandas Excel writer and output the Excel file.
writer2.save()
reader2 = pd.read_excel(r'All_rounders.xlsx')
print(reader2)
df6.to_excel(writer2,index=False,header=False)
df7.to_excel(writer2,index=False,header=False)
df8.to_excel(writer2,index=False,header=False)
#------------------------------TEAMS----------------------------------#
driver.find_element_by_xpath("//a[@id='teams-tab']").click()
m=driver.find_elements_by_xpath("//a[@id='teams-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-brdr-thin-btm text-center')]")
l9=[]
for l4 in m:
    if l4.text!='':
        l9.append(l4.text.split("\n"))
print(l9,end=" ")
driver.find_element_by_xpath("//a[@id='teams-odis-tab']").click()
n=driver.find_elements_by_xpath("//a[@id='teams-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-brdr-thin-btm text-center')]")
l10=[]
for l5 in n:
    if l5.text!='':
        l10.append(l5.text.split("\n"))
print(l10,end=" ")
driver.find_element_by_xpath("//a[@id='teams-t20s-tab']").click()
o=driver.find_elements_by_xpath("//a[@id='teams-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-brdr-thin-btm text-center')]")
l11=[]
for l6 in o:
    if l6.text!='':
        l11.append(l6.text.split("\n"))
print(l11,end=" ")
# dataframe
writer3 = pd.ExcelWriter('Teams.xlsx', engine='xlsxwriter')
df9 = pd.DataFrame(l9, columns = ["Position","Team","Rating","Points"])
df10 = pd.DataFrame(l10, columns = ["Position","Team","Rating","Points"])
df11 = pd.DataFrame(l11, columns = ["Position","Team","Rating","Points"])
#df9.drop(columns='NAN',axis="columns",inplace=True)
time.sleep(2)
writer3 = pd.ExcelWriter('Teams.xlsx', engine='xlsxwriter')
writer3.save()
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer3 = pd.ExcelWriter('Teams.xlsx', engine='xlsxwriter')
# Convert the dataframe to an XlsxWriter Excel object.
df9.to_excel(writer3, sheet_name='Teams-TEST', index=False)
df10.to_excel(writer3, sheet_name='Teams-ODI', index=False)
df11.to_excel(writer3, sheet_name='Teams-T20', index=False)
# Close the Pandas Excel writer and output the Excel file.
writer3.save()
reader3 = pd.read_excel(r'Teams.xlsx')
print(reader3)
df9.to_excel(writer3,index=False,header=False)
df10.to_excel(writer3,index=False,header=False)
df11.to_excel(writer3,index=False,header=False)
writer3.close()
writer2.close()
writer.close()
writer1.close()
driver.close()
# Out:
# [['1', '    –', 'Kane Williamson', 'NEW ZEALAND', '901'], ['2', '    –', 'Steven Smith', 'AUSTRALIA', '891'], ['3', '    –', 'Marnus Labuschagne', 'AUSTRALIA', '878'], ['4', '    1', 'Joe Root', 'ENGLAND', '846'], ['5', '    1', 'Virat Kohli', 'INDIA', '791'], ['6', '    –', 'Rohit Sharma', 'INDIA', '764'], ['7', '    –', 'Rishabh Pant', 'INDIA', '746'], ['8', '    –', 'David Warner', 'AUSTRALIA', '724'], ['9', '    –', 'Quinton de Kock', 'SOUTH AFRICA', '717'], ['10', '    –', 'Henry Nicholls', 'NEW ZEALAND', '714'], ['11', '    –', 'Babar Azam', 'PAKISTAN', '714'], ['12', '    –', 'Dimuth Karunaratne', 'SRI LANKA', '712'], ['13', '    1', 'Ross Taylor', 'NEW ZEALAND', '693'], ['14', '    1', 'Ajinkya Rahane', 'INDIA', '684'], ['15', '    –', 'Ben Stokes', 'ENGLAND', '684'], ['16', '    1', 'Tom Latham', 'NEW ZEALAND', '677'], ['17', '    1', 'Azhar Ali', 'PAKISTAN', '673'], ['18', '    2', 'Cheteshwar Pujara', 'INDIA', '668'], ['19', '    –', 'Dean Elgar', 'SOUTH AFRICA', '661'], [
# ...
